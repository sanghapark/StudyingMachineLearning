# %% [markdown]
# # Good initialization is to dry sample from a Gaussian centered at zero with variance one over D.

# %%
import numpy as np

# %% [markdown]
# $
# E(w_1, w_2) = w_1^2 + w_2^4
# $
# <br>
# Try to optimize.

# %%
w1 = 30
w2 = 10

learning_rate = 0.1

for i in range(100):
    w1 -= learning_rate * (2*w1)
    w2 -= 0.0049 * (4*w2*w2*w2)
    print(w1, w2)
# learning_rate * (4 * w2 * w2 *w2)
# Out:
# 24.0 -9.599999999999998
# 19.2 7.740825599999987
# 15.36 -1.3503054918384532
# 12.288 -1.3020493970078508
# 9.830400000000001 -1.2587842231095316
# 7.864320000000001 -1.2196902378768937
# 6.291456000000001 -1.1841267199309315
# 5.033164800000001 -1.1515842423205356
# 4.0265318400000005 -1.1216517270927502
# 3.2212254720000004 -1.0939931292597807
# 2.5769803776000004 -1.0683305765315194
# 2.0615843020800004 -1.044431944265639
# 1.6492674416640003 -1.0221015438579097
# 1.3194139533312002 -1.0011730389544835
# 1.0555311626649602 -0.9815039833223241
# 0.8444249301319682 -0.9629715574878602
# 0.6755399441055745 -0.9454692039910505
# 0.5404319552844596 -0.9289039448654649
# 0.4323455642275677 -0.9131942231088166
# 0.34587645138205414 -0.8982681509186365
# 0.2767011611056433 -0.8840620768054711
# 0.22136092888451464 -0.8705194049615878
# 0.17708874310761172 -0.8575896158661112
# 0.14167099448608939 -0.8452274486851565
# 0.11333679558887151 -0.8333922147065366
# ...
